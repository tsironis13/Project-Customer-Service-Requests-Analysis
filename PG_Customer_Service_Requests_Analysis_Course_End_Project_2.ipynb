# %%
# import required libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows',None)

# %%
# read dataset
df = pd.read_csv("311_Service_Requests_from_2010_to_present_1.csv")

# %%
# print the top 5 records
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %%
# print the last 5 records
df.tail()
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# 364555    29607589  01/01/2015 12:01:30 AM  01/01/2015 12:20:33 AM   NYPD
# 364556    29610889  01/01/2015 12:01:29 AM  01/01/2015 02:42:22 AM   NYPD
# 364557    29611816  01/01/2015 12:00:50 AM  01/01/2015 02:47:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# 364553  New York City Police Department          Illegal Parking
# 364554  New York City Police Department          Noise - Vehicle
# 364555  New York City Police Department  Noise - Street/Sidewalk
# 364556  New York City Police Department         Blocked Driveway
# 364557  New York City Police Department         Blocked Driveway
#
#               Descriptor    Location Type  Incident Zip      Incident Address  \
# ...

# %%
# print the columns of the dataset
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
# print the numerical variables of the dataset
df.select_dtypes(exclude='O').columns
# Out:
# Index(['Unique Key', 'Incident Zip', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Garage Lot Name', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# print the categorical variables of the dataset
df.select_dtypes(include='O').columns
# Out:
# Index(['Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Address',
#        'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Ferry Direction', 'Ferry Terminal Name', 'Location'],
#       dtype='object')

# %%
# print the shape of the dataset
df.shape
# Out:
# (364558, 53)

# %%
# print the variables with null values
df.isna().sum(axis = 0)[df.isna().sum(axis = 0) > 0]
# Out:
# Closed Date                         2381
# Descriptor                          6501
# Location Type                        133
# Incident Zip                        2998
# Incident Address                   51699
# Street Name                        51699
# Cross Street 1                     57188
# Cross Street 2                     57805
# Intersection Street 1             313438
# Intersection Street 2             314046
# Address Type                        3252
# City                                2997
# Landmark                          364183
# Facility Type                       2389
# Due Date                               3
# Resolution Action Updated Date      2402
# X Coordinate (State Plane)          4030
# Y Coordinate (State Plane)          4030
# School Region                          1
# School Code                            1
# School Zip                             1
# School or Citywide Complaint      364558
# Vehicle Type                      364558
# ...

# %%
# Draw a frequency plot to show the number of null values in each column of the DataFrame
null_values = df.isna().sum(axis = 0)[df.isna().sum(axis = 0) > 0]

plt.figure(figsize=(9,14))
sns.barplot(x=null_values.values, y=null_values.index)
# Out:
# <AxesSubplot: >

# %%
# Remove the records whose Closed Date values are null
cl_date_null_values = df['Closed Date'].isna().sum(axis=0)

percentage_of_missing_cl_date_values = (cl_date_null_values/df.shape[0])*100
percentage_of_missing_cl_date_values
# Out:
# 0.6531196682009447

# %%
print("The total rows of data set before removing the rows: {}".format(df.shape[0]))

df.dropna(subset=['Closed Date'], inplace = True)

print("The total rows of data set after removing the rows: {}".format(df.shape[0]))
# Out:
# The total rows of data set before removing the rows: 364558
# The total rows of data set after removing the rows: 362177

# %%
# no rows with 'Closed Date' null values exist
df['Closed Date'].isna().sum(axis=0)
# Out:
# 0

# %%
# Calculate the time elapsed in closed and creation date
created_date = pd.to_datetime(df['Created Date'])
closed_date = pd.to_datetime(df['Closed Date'])

df['Request_Closing_Time'] = closed_date - created_date

df.tail()
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# 364555    29607589  01/01/2015 12:01:30 AM  01/01/2015 12:20:33 AM   NYPD
# 364556    29610889  01/01/2015 12:01:29 AM  01/01/2015 02:42:22 AM   NYPD
# 364557    29611816  01/01/2015 12:00:50 AM  01/01/2015 02:47:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# 364553  New York City Police Department          Illegal Parking
# 364554  New York City Police Department          Noise - Vehicle
# 364555  New York City Police Department  Noise - Street/Sidewalk
# 364556  New York City Police Department         Blocked Driveway
# 364557  New York City Police Department         Blocked Driveway
#
#               Descriptor    Location Type  Incident Zip      Incident Address  \
# ...

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %%
# Convert the calculated date to seconds to get a better representation
df['Request_Closing_Time'] = df['Request_Closing_Time'] / np.timedelta64(1, 's')

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %%
# View the descriptive statistics for the newly created column
# we can see that the average response time in seconds is 15113 seconds, which is approximately 4hours and 11minutes
df['Request_Closing_Time'].describe()
# Out:
# count    3.621770e+05
# mean     1.511330e+04
# std      2.110255e+04
# min      6.100000e+01
# 25%      4.533000e+03
# 50%      9.616000e+03
# 75%      1.887800e+04
# max      2.134342e+06
# Name: Request_Closing_Time, dtype: float64

# %%
# Check the number of null values in the 'Complaint_Type' and 'City'
df['City'].isna().sum(axis=0)
# Out:
# 674

# %%
df['Complaint Type'].isna().sum(axis=0)
# Out:
# 0

# %%
# Impute the NA value with 'Unknown City'
df['City'] = df['City'].fillna('Unknown City')

# %%
# Draw a frequency plot for the complaints in each city
plt.figure(figsize=(10,14))
sns.countplot(y ='City', hue = "Complaint Type", data = df, width=4)
 
# Show the plot
plt.show()

# %%
# Create a scatter and hexbin plot of the concentration of complaints across Brooklyn
df_brkln = df.loc[(df['City'] == 'BROOKLYN')]

# %%
# scatter plot
df_brkln[['Longitude', 'Latitude']].plot(kind = 'scatter', x='Longitude', y='Latitude', title = 'Complaints Concentration in Brooklyn', figsize = (10, 8));

# %%
# hexbin plot
df_brkln[['Longitude', 'Latitude']].plot(kind = 'hexbin', x='Longitude', y='Latitude', gridsize=40,
    colormap = 'jet', mincnt=1, title = 'Complaints Concentration in Brooklyn', figsize = (10, 8));

# %%
# Plot a bar graph to show the types of complaints
sns.countplot(y='Complaint Type', data=df)
# Out:
# <AxesSubplot: xlabel='count', ylabel='Complaint Type'>

# %%
# Check the frequency of various types of complaints for New York City
df_ny = df[df["City"] == 'NEW YORK']

sns.countplot(y='Complaint Type', data=df_ny).set(title='Frequency of complaints for New York City')
# Out:
# [Text(0.5, 1.0, 'Frequency of complaints for New York City')]

# %%
# find the top 10 complaint types
df.groupby(['Complaint Type'])['Complaint Type'].count().sort_values(ascending=False).head(10)
# Out:
# Complaint Type
# Blocked Driveway           100624
# Illegal Parking             91716
# Noise - Street/Sidewalk     51139
# Noise - Commercial          43751
# Derelict Vehicle            21518
# Noise - Vehicle             19301
# Animal Abuse                10530
# Traffic                      5196
# Homeless Encampment          4879
# Vending                      4185
# Name: Complaint Type, dtype: int64

# %%
# Display the various types of complaints in each city
df.groupby(['City', 'Complaint Type'])['City'].agg(['count'])
# Out:
#                                                count
# City                Complaint Type
# ARVERNE             Animal Abuse                  46
#                     Blocked Driveway              50
#                     Derelict Vehicle              32
#                     Disorderly Youth               2
#                     Drinking                       1
#                     Graffiti                       1
#                     Homeless Encampment            4
#                     Illegal Parking               62
#                     Noise - Commercial             2
#                     Noise - House of Worship      14
#                     Noise - Park                   2
#                     Noise - Street/Sidewalk       29
#                     Noise - Vehicle               10
#                     Panhandling                    1
#                     Traffic                        1
#                     Urinating in Public            1
# ...

# %%
# Create a DataFrame, df_new, which contains cities as columns and complaint types in rows
df_new = pd.crosstab(df['Complaint Type'], df['City'])
df_new
# Out:
# City                       ARVERNE  ASTORIA  Astoria  BAYSIDE  BELLEROSE  \
# Complaint Type
# Agency Issues                    0        0        0        0          0
# Animal Abuse                    46      170        0       53         15
# Animal in a Park                 0        0        0        0          0
# Bike/Roller/Skate Chronic        0       16        0        0          1
# Blocked Driveway                50     3436      159      514        138
# Derelict Vehicle                32      426       14      231        120
# Disorderly Youth                 2        5        0        2          2
# Drinking                         1       43        0        1          1
# Graffiti                         1        4        0        3          0
# Homeless Encampment              4       32        0        2          1
# Illegal Fireworks                0        4        0        0          1
# Illegal Parking                 62     1340      277      638        132
# ...

# %%
# Draw another chart that shows the types of complaints in each city in a single chart, 
# where different colors show the different types of complaints
crosstab = pd.crosstab(index=df["City"], columns=df["Complaint Type"])
crosstab

crosstab.plot(kind="bar", figsize=(12,8), stacked=True)
# Out:
# <AxesSubplot: xlabel='City'>

# %%
# Sort the complaint types based on the average Request_Closing_Timegrouping them for different locations
df_gr_loc_mean = df.groupby(['Complaint Type', 'Location Type'])['Request_Closing_Time'].agg(['mean']).head(50)
print(df_gr_loc_mean)
# Out:
#                                                               mean
# Complaint Type            Location Type
# Animal Abuse              Commercial                  1.623899e+04
#                           House and Store             1.750501e+04
#                           Park/Playground             1.343101e+04
#                           Parking Lot                 1.823671e+04
#                           Residential Building        1.603562e+04
#                           Residential Building/House  1.868705e+04
#                           Store/Commercial            1.577307e+04
#                           Street/Sidewalk             1.772498e+04
#                           Subway Station              1.103808e+04
# Animal in a Park          Park                        1.212634e+06
# Bike/Roller/Skate Chronic Residential Building/House  1.342132e+04
#                           Store/Commercial            1.280402e+04
# ...

# %%
df_gr_loc_mean.sort_values(by='mean',ascending=False).head(50)
# Out:
#                                                               mean
# Complaint Type            Location Type
# Animal in a Park          Park                        1.212634e+06
# Derelict Vehicle          Roadway Tunnel              5.474012e+04
# Graffiti                  Street/Sidewalk             3.581033e+04
# Derelict Vehicle          Highway                     2.537128e+04
#                           Street/Sidewalk             2.535475e+04
#                           Vacant Lot                  2.427372e+04
# Graffiti                  Store/Commercial            2.049253e+04
#                           Residential Building/House  1.955515e+04
# Animal Abuse              Residential Building/House  1.868705e+04
#                           Parking Lot                 1.823671e+04
#                           Street/Sidewalk             1.772498e+04
#                           House and Store             1.750501e+04
# ...

# %%
#Visualize the average of 'Request_Closing_Time' across different complaint types

#use as_index=False to output as DataFrame
avg_cmpl_types = df.groupby('Complaint Type', as_index=False)['Request_Closing_Time'].mean()

print(avg_cmpl_types)
sns.barplot(y = 'Complaint Type', x = 'Request_Closing_Time',data=avg_cmpl_types)
# Out:
#                Complaint Type  Request_Closing_Time
# 0               Agency Issues          1.828912e+04
# 1                Animal Abuse          1.803256e+04
# 2            Animal in a Park          1.212634e+06
# 3   Bike/Roller/Skate Chronic          1.312369e+04
# 4            Blocked Driveway          1.623252e+04
# 5            Derelict Vehicle          2.535960e+04
# 6            Disorderly Youth          1.236375e+04
# 7                    Drinking          1.382130e+04
# 8                    Graffiti          2.327634e+04
# 9         Homeless Encampment          1.545138e+04
# 10          Illegal Fireworks          1.011348e+04
# 11            Illegal Parking          1.565044e+04
# 12         Noise - Commercial          1.108576e+04
# 13   Noise - House of Worship          1.139109e+04
# 14               Noise - Park          1.222606e+04
# 15    Noise - Street/Sidewalk          1.223130e+04
# 16            Noise - Vehicle          1.256180e+04
# ...

# %%
dataset = {}

for i in df['Complaint Type'].unique():
    dataset[i] = df[df['Complaint Type']== i]['Request_Closing_Time']

# %%
# perform Kruskal-Wallis H test to check whether the average response time across different complaint types is similar or not

# Ho: the avg response time across complaint types is similar
# Ha: the avg response time across complaint types is not similar

st.kruskal(dataset['Graffiti'], dataset['Illegal Parking'], dataset['Bike/Roller/Skate Chronic'],
                      dataset['Vending'],dataset['Urinating in Public'],dataset['Traffic'],dataset['Squeegee'],
                      dataset['Posting Advertisement'],dataset['Panhandling'],
                     dataset['Blocked Driveway'], dataset['Derelict Vehicle'], dataset['Animal Abuse'], dataset['Disorderly Youth'],
                     dataset['Drinking'], dataset['Homeless Encampment'], dataset['Illegal Fireworks'], dataset['Noise - Commercial'],
                      dataset['Noise - House of Worship'], dataset['Noise - Park'], dataset['Noise - Street/Sidewalk'], dataset['Noise - Vehicle'])
# Out:
# KruskalResult(statistic=11984.240525835248, pvalue=0.0)

# %% [markdown]
# ### The p-value is 0, the null hypothesis is rejected. There is a significant difference between the average request closing times among the different complaint types.
